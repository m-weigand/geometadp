# %%
import datetime
import numpy as np
import pandas as pd

from ipywidgets import widgets


"""
db tab
"""

df = pd.read_csv(
    'https://raw.githubusercontent.com/agrogeophy/catalog/master/db.csv')
#df = df.drop(df.columns[[0]], axis=1)

df['contribution_type'].unique().tolist()

textbox = widgets.Dropdown(
    description='instrument:   ',
    options=df['contribution_type'].unique().tolist(),
    disabled=False
)

display(df)
display(textbox)
# Out:
#     id surname          name  \
# 0    1     NaN           NaN
# 1    2     NaN           NaN
# 2    3     NaN           NaN
# 3    4     NaN           NaN
# 4    5     NaN           NaN
# ..  ..     ...           ...
# 93  94     Jan  Vanderborght
# 94  95     Jan  Vanderborght
# 95  96    Tina        Martin
# 96  97    Tina        Martin
# 97  98    Tina        Martin
#
#                                          organisation  \
# 0   Department of Crop, Forest and Environmental S...
# 1        Department of Forest Science and Environment
# 2   Department of Crop, Forest and Environmental S...
# 3   Department of Crop, Forest and Environmental S...
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                          KU Leuven
# 95                                    Lund University
# 96                                    Lund University
# 97                                    Lund University
#
#                            email          contribution_type  \
# 0                            NaN  Peer reviewed publication
# 1                            NaN  Peer reviewed publication
# 2                            NaN  Peer reviewed publication
# 3                            NaN  Peer reviewed publication
# 4                            NaN  Peer reviewed publication
# ..                           ...                        ...
# 93  j.vanderborght@fz-juelich.de  Peer reviewed publication
# 94  j.vanderborght@fz-juelich.de  Peer reviewed publication
# 95         tina.martin@tg.lth.se  Peer reviewed publication
# 96         tina.martin@tg.lth.se  Peer reviewed publication
# 97         tina.martin@tg.lth.se  Peer reviewed publication
#
#                                                 title publication_date  \
# 0   In situ detection of tree root distribution an...             2008
# 1   Preliminary use of ground-penetrating radar an...             2008
# 2   Multi-electrode 3D resistivity imaging of alfa...             2009
# 3   Multielectrode Geoelectrical Tomography for th...             2010
# 4   The use of three geophysical methods for 3D im...             2010
# ..                                                ...              ...
# 93  Geophysical Methods for Field-Scale Imaging of...             2013
# 94  Spatial variability of soil water content and ...             2017
# 95       Low-Frequency Impedance Spectroscopy of Wood       10/19/2015
# 96  Complex Resistivity Tomography (CRT) for fungu...        7/24/2013
# 97            Complex resistivity measurements on oak         3/5/2010
#
#                                      publication_link  \
# 0      https://dx.doi.org/10.1093/treephys/28.10.1441
# 1                  https://dx.doi.org/10.1071/FP08062
# 2        https://dx.doi.org/10.1016/j.eja.2009.08.005
# 3             https://dx.doi.org/10.4081/ija.2010.257
# 4                  https://dx.doi.org/10.1071/EG09034
# ..                                                ...
# 93      https://dx.doi.org//10.2136/sssaspecpub61.c12
# 94  https://dx.doi.org//10.1016/j.geoderma.2017.10...
# 95                https://doi.org/10.5171/2015.910447
# 96          https://doi.org/10.1007/s10342-013-0711-4
# 97          https://doi.org/10.1007/s00107-010-0493-z
#
#                               authors  ...    water      ancillary_data  \
# 0                        Amato et al.  ...      NaN                 NaN
# 1                       Zenone et al.  ...      NaN                 NaN
# 2                        Amato et al.  ...      NaN                 NaN
# 3                        Amato et al.  ...      NaN                 NaN
# 4                              Leucci  ...      NaN                 NaN
# ..                                ...  ...      ...                 ...
# 93                                NaN  ...      NaN                 NaN
# 94                                NaN  ...  rainfed  Soil Water Content
# 95  T. Martin; S. Nordsiek; A. Weller  ...      NaN                 NaN
# 96             T. Martin; T. GÃ¼nther  ...      NaN                 NaN
# 97                          T. Martin  ...      NaN                 NaN
#
#     notebook_filename notebook_purpose  \
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ..                ...              ...
# 93                NaN              NaN
# 94                NaN              NaN
# 95                NaN              NaN
# 96                NaN              NaN
# 97                NaN              NaN
#
#                                          dataset_link dataset_licence  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# ..                                                ...             ...
# 93                                                NaN             NaN
# 94                                                NaN             NaN
# 95  https://ibimapublishing.com/articles/SPEC/2015...     Open source
# 96                                                NaN             NaN
# 97                                                NaN     Open source
#
#    dataset_comment comment cover_picture cover_picture_Licence
# 0              NaN     NaN           NaN                   NaN
# 1              NaN     NaN           NaN                   NaN
# 2              NaN     NaN           NaN                   NaN
# 3              NaN     NaN           NaN                   NaN
# 4              NaN     NaN           NaN                   NaN
# ..             ...     ...           ...                   ...
# 93             NaN     NaN           NaN                   NaN
# 94             NaN     NaN      Fig8.png                   NaN
# 95             NaN     NaN           NaN                   NaN
# 96     Open source     NaN           NaN                   NaN
# 97             NaN     NaN           NaN                   NaN
#
# [98 rows x 36 columns]
# Dropdown(description='instrument:   ', options=('Peer reviewed publication', 'Book', 'Notebook'), value='Peer …
