# %%
# merge dataset into xarray/hdf5 containers

# %%
import pandas as pd

np.random.seed(0)
temperature = 15 + 8 * np.random.randn(2, 2, 3)
precipitation = 10 * np.random.rand(2, 2, 3)
lon = [[-99.83, -99.32], [-99.79, -99.23]]
lat = [[42.25, 42.21], [42.63, 42.59]]
time = pd.date_range("2014-09-06", periods=3)
reference_time = pd.Timestamp("2014-09-05")

ds = xr.Dataset(
    data_vars=dict(
        temperature=(["x", "y", "time"], temperature),
        precipitation=(["x", "y", "time"], precipitation),
    ),
    coords=dict(
        lon=(["x", "y"], lon),
        lat=(["x", "y"], lat),
        time=time,
        reference_time=reference_time,
    ),
    attrs=dict(description="Weather related data."),
)
ds.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-3ed62bc99d17> in <module>
#      22     attrs=dict(description="Weather related data."),
#      23 )
# ---> 24 ds.plot()
#
# ~\Anaconda3\lib\site-packages\xarray\plot\dataset_plot.py in __call__(self, *args, **kwargs)
#     172
#     173     def __call__(self, *args, **kwargs):
# --> 174         raise ValueError(
#     175             "Dataset.plot cannot be called directly. Use "
#     176             "an explicit plot method, e.g. ds.plot.scatter(...)"
#
# ValueError: Dataset.plot cannot be called directly. Use an explicit plot method, e.g. ds.plot.scatter(...)

# %%
ds = xr.tutorial.load_dataset('air_temperature')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 241.2 242.5 243.5 ... 296.5 296.2 295.7
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
import numpy as np
import h5py

hf.close()

# dataset of ERT
d1 = np.random.random(size = (2,3))

# dataset of meteo data
d2 = np.random.random(size = (2,5))

hf = h5py.File('data.h5', 'w')

hf.create_dataset('dataset_1', data=d1)
hf.create_dataset('dataset_2', data=d2)

g1 = hf.create_group('group1')

g1.create_dataset('data1',data=d1)
g1.create_dataset('data2',data=d1)

g2 = hf.create_group('group2/subfolder')

print(list(hf.keys()))
print(list(hf['dataset_1']))

hf.close()
# Out:
# ['dataset_1', 'dataset_2', 'group1', 'group2']
# [array([0.35507311, 0.38423515, 0.14724067]), array([0.43045815, 0.68533251, 0.07828075])]

# %%
import xarray as xr
