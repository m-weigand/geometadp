# %%
# import .dat with REDA

# %%
import reda
import os
import pandas as pd
import numpy as np

ert = reda.ERT()
print(os.getcwd())

ert.import_pygimli('ERT_TL_Garre_new/20180612_18H00_20480000_1909.dat')

if hasattr(ert.data, 'chargeability'):
    print('ch')
    
print(len(ert.electrode_positions))
if len(ert.electrode_positions)>0:
    print('ert.electrode_positions')
    
df0 = ert.data

ert1 = reda.ERT()
ert1.import_pygimli('ERT_TL_Garre_new/20180613_01H00_19970222_1920.dat')
df1 = ert1.data

ert2 = reda.ERT()
ert2.import_pygimli('ERT_TL_Garre_new/20180613_07H00_19970222_1918.dat')
df2 = ert2.data

time =  pd.date_range("2018-06-13", periods=3)
reference_time = pd.Timestamp("2018-06-13")
lat = ert.electrode_positions['X']
lon = ert.electrode_positions['Z']
R = ert.data['R']

print(df0)
Rs= np.zeros([len(R),len(time)])
print(Rs.shape)
for i in range(3):
    df_name = 'df' + str(i)
    print(i)
    Rs[:,i]= eval(df_name  + str(['R']))
    
print(Rs.shape)
# Out:
# C:\Users\Benjamin\Documents\Z_Database\geometadp\test_ERT_TL
# generating ids
# assigning ids
# 32
# ert.electrode_positions
# generating ids
# assigning ids
# generating ids
# assigning ids
#        a   b   m   n           R       err    id norrec
# 516    1   4   2   3  1429.71400  0.707158    39    nor
# 1187   2   3   1   4  1419.60900  0.000000    39    rec
# 671    3   4   1   2  -848.24160  0.668376    79    rec
# 0      1   2   3   4  -840.13740  0.222768    79    nor
# 517    2   5   3   4  2690.40400  0.646390    80    nor
# ...   ..  ..  ..  ..         ...       ...   ...    ...
# 1184  31  32  27  28   -75.23542 -0.001577  1339    rec
# 1185  31  32  28  29  -300.13240  0.164835  1340    rec
# 514   28  29  31  32  -309.10790  1.041551  1340    nor
# 515   29  30  31  32  -791.96620  4.183934  1341    nor
# 1186  31  32  29  30  -793.22690  0.425602  1341    rec
#
# [1342 rows x 8 columns]
# (1342, 3)
# 0
# 1
# 2
# (1342, 3)

# %%
df_name + str(['R'])
# Out:
# "df0['R']"

# %%
ds = xr.Dataset(
    data_vars=dict(
        resistance=(["x", "z", "time"], temperature),
        error=(["x", "z", "time"], precipitation),
    ),
    coords=dict(
        lon=(["z"], lon),
        lat=(["x"], lat),
        time=time,
        reference_time=reference_time,
    ),
    attrs=dict(description="ERT related data."),
)

# %%
import h5py
import xarray as xr

# %%
arrayX = df.to_xarray()
arrayX

# add time dimension
# add spatial dimension
np.random.seed(0)
temperature = 15 + 8 * np.random.randn(2, 2, 3)
precipitation = 10 * np.random.rand(2, 2, 3)
lon = [[-99.83, -99.32], [-99.79, -99.23]]
lat = [[42.25, 42.21], [42.63, 42.59]]
time = pd.date_range("2014-09-06", periods=3)
reference_time = pd.Timestamp("2014-09-05")

ds = xr.Dataset(
    data_vars=dict(
        temperature=(["x", "y", "time"], temperature),
        precipitation=(["x", "y", "time"], precipitation),
    ),
    coords=dict(
        lon=(["x", "y"], lon),
        lat=(["x", "y"], lat),
        time=time,
        reference_time=reference_time,
    ),
    attrs=dict(description="Weather related data."),
)
ds.plot()
# Out:
# <xarray.Dataset>
# Dimensions:  (index: 1342)
# Coordinates:
#   * index    (index) int64 516 1187 671 0 517 1188 ... 1184 1185 514 515 1186
# Data variables:
#     a        (index) int32 1 2 3 1 2 3 3 1 4 1 ... 31 25 26 31 27 31 31 28 29 31
#     b        (index) int32 4 3 4 2 5 4 5 7 5 2 ... 32 26 27 32 28 32 32 29 30 32
#     m        (index) int32 2 1 1 3 3 2 1 3 1 4 ... 25 31 31 26 31 27 28 31 31 29
#     n        (index) int32 3 4 2 4 4 5 7 5 2 5 ... 26 32 32 27 32 28 29 32 32 30
#     R        (index) float64 1.43e+03 1.42e+03 -848.2 ... -309.1 -792.0 -793.2
#     err      (index) float64 0.7072 0.0 0.6684 0.2228 ... 1.042 4.184 0.4256
#     id       (index) int64 39 39 79 79 80 80 ... 1339 1339 1340 1340 1341 1341
#     norrec   (index) object 'nor' 'rec' 'rec' 'nor' ... 'rec' 'nor' 'nor' 'rec'
