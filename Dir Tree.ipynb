# %%
# !pip install treelib
from treelib import Node, Tree

tree = Tree()



tree.show()
# Out:
# Collecting treelib
#   Downloading treelib-1.6.1.tar.gz (24 kB)
# Requirement already satisfied: future in c:\users\benjamin\anaconda3\lib\site-packages (from treelib) (0.18.2)
# Building wheels for collected packages: treelib
#   Building wheel for treelib (setup.py): started
#   Building wheel for treelib (setup.py): finished with status 'done'
#   Created wheel for treelib: filename=treelib-1.6.1-py3-none-any.whl size=18374 sha256=8575b30f7cc296880c3bdac467e1ef85b2dffcaa01b681480d1127d9a4c269f8
#   Stored in directory: c:\users\benjamin\appdata\local\pip\cache\wheels\71\df\8b\6b005e3bb9b275c24dfc392cda334f43f132e85a6f17cfad3a
# Successfully built treelib
# Installing collected packages: treelib
# Successfully installed treelib-1.6.1
# Harry
# ├── Bill
# └── Jane
#     ├── Diane
#     │   └── Mary
#     └── Mark

# %%
# !pip install directory_tree
from directory_tree import display_tree
import os 

directory_path = os.getcwd()
# Main Method
if __name__ == '__main__':
    display_tree(directory_path)
# Out:
# Requirement already satisfied: directory_tree in c:\users\benjamin\anaconda3\lib\site-packages (0.0.2)
#
# $ Operating System : Windows
# $ Path : C:\Users\Benjamin\Documents\Z_Database\geometadp
#
# *************** Directory Tree ***************
#
# geometadp/
# ├── .git/
# │   ├── COMMIT_EDITMSG
# │   ├── config
# │   ├── description
# │   ├── FETCH_HEAD
# │   ├── HEAD
# │   ├── hooks/
# │   │   ├── applypatch-msg.sample
# │   │   ├── commit-msg.sample
# │   │   ├── fsmonitor-watchman.sample
# │   │   ├── post-update.sample
# │   │   ├── pre-applypatch.sample
# │   │   ├── pre-commit.sample
# │   │   ├── pre-merge-commit.sample
# │   │   ├── pre-push.sample
# │   │   ├── pre-rebase.sample
# │   │   ├── pre-receive.sample
# │   │   ├── prepare-commit-msg.sample
# │   │   └── update.sample
# │   ├── index
# │   ├── info/
# │   │   ├── exclude
# │   │   └── refs
# │   ├── logs/
# │   │   ├── HEAD
# │   │   └── refs/
# │   │       ├── heads/
# │   │       │   ├── gh-pages
# │   │       │   └── main
# │   │       └── remotes/
# │   │           ├── origin/
# │   │           │   ├── gh-pages
# │   │           │   ├── HEAD
# │   │           │   └── main
# │   │           └── upstream/
# │   │               └── main
# │   ├── objects/
# │   │   ├── 00/
# │   │   │   ├── 86cd718fcd400079506bb09c5634315133b2a9
# │   │   │   └── ef283edaca5367972ab0efaaf71d101dff189d
# │   │   ├── 02/
# │   │   │   └── a5eabc315c6cede8e61734f2eefd14a3ade7ac
# │   │   ├── 03/
# │   │   │   ├── 0b90b7048cea967172c12974082f6854e942c8
# │   │   │   ├── 5744932a00ef753817ea45b1a01bee9824beaf
# │   │   │   ├── a1574857ffb08a2e72e8c6f54d7131f02371eb
# │   │   │   └── cf57e9b12dd573668c85359d92ee3531dc9415
# │   │   ├── 05/
# │   │   │   └── bd1b1e02e61e3359f5f9068cf2cf01b54051e2
# │   │   ├── 08/
# │   │   │   ├── 06aaa61bf6c538d5037f161115f6831ed7f4e2
# │   │   │   ├── 07176ec0cb13c1214ddacecadfbfde5ecd7514
# │   │   │   └── 88c15c01e7c27c6bc5cb45859dddd8a31d6854
# │   │   ├── 09/
# │   │   │   └── c87a780d4094e4eeb87333f85205402583017b
# │   │   ├── 0c/
# │   │   │   └── 69250162b516cb87ef726867995c8ad176504b
# │   │   ├── 0d/
# │   │   │   └── 4bcc60665a2e51b7dad58b23cb2f6b65e4713a
# │   │   ├── 0e/
# │   │   │   └── cd4cf3b19ff6b9d4546a8bec8a7563508d715b
# │   │   ├── 0f/
# │   │   │   └── 3d0f837d24834b9b5b0a6b735459c56f5e75c3
# │   │   ├── 10/
# │   │   │   ├── a5fc1be4f35bec1c57d8ee71d57860a76a2071
# │   │   │   └── eec2fac6c6b330917505ae1830ba95714a2719
# │   │   ├── 11/
# │   │   │   ├── 8c33a8d2d209a83c30ec3e2b03fa0e2c6a8c85
# │   │   │   └── e3f2a5f0f9b8c7ef6affae8c543d20f7c112be
# │   │   ├── 12/
# │   │   │   └── fef3804e8b46157d0cf2d0c98f3cede54a5f2e
# │   │   ├── 15/
# │   │   │   ├── 5a3f37f59e420d7a15ebf06200182a8412898a
# │   │   │   └── 8f1d09fb8ae0e0787cba6979e4363f8ee1b271
# │   │   ├── 16/
# │   │   │   └── 5f3dae7dc98d6dd7cb1c936d660e30bcbc973d
# │   │   ├── 1c/
# │   │   │   ├── 002e5702accfb832a395f8e2d27903db22117e
# │   │   │   └── cdf88144d45e7a49dcdf3e3d5fb490ef996e98
# │   │   ├── 1d/
# │   │   │   ├── 23c7066e095b5bff2c373d4064dc4f33659783
# │   │   │   └── b0a123f4db3b7e5d147f16f19a60c691ae4390
# │   │   ├── 1e/
# │   │   │   ├── 99ce38e7ea80b5314f961652f97aebef29a994
# │   │   │   └── ba4afa89b7515d6e865b8a1a65947324869028
# │   │   ├── 21/
# │   │   │   └── dce0e0f782388c24686b66951a9d4914b280f3
# │   │   ├── 22/
# │   │   │   ├── 495d9da34d0d88fd6fd08dc2fd314f18093909
# │   │   │   └── c8e4e3c47efba8ef274b9fd54f94ccc130e7a3
# │   │   ├── 23/
# │   │   │   └── 290c68cf42290f3e40cf46fa56fd45ae3b1a9a
# │   │   ├── 24/
# │   │   │   └── 04486448bf7324b1800d7c5cc0092188ea4dd7
# │   │   ├── 27/
# │   │   │   ├── 8b4361d233cf8b319953894b2edd86897130ae
# │   │   │   ├── 9f6179b1af045a21e07e38bfecd0df32d1d340
# │   │   │   ├── b6abca8b1db41228203a9eeff0116b7356bf06
# │   │   │   └── c9a1f5b3e846e7885d499673ce99767151bcc0
# │   │   ├── 29/
# │   │   │   ├── 66ec8b9d56fc6610aa86119f43e8be7b54cf47
# │   │   │   └── f691d5ed0c2d3d224423bb0288e6bd59292511
# │   │   ├── 2a/
# │   │   │   └── a36fbaf49a32574f5a91717b718ee208a08d7c
# │   │   ├── 2b/
# │   │   │   ├── 43bd062e9689f9f4016931d08e7143d555539d
# │   │   │   └── 9c3c7a6c744742f6bd0c15815a2378723c10b3
# │   │   ├── 2f/
# │   │   │   ├── 6b31f3c438c546958ff2f642bcbcdd4a9783cf
# │   │   │   ├── 7ca78a1eb34f0f98feb07ab1231d077b248940
# │   │   │   └── 909ee9a34540e5e473bd237fe8ca33127191c1
# │   │   ├── 31/
# │   │   │   ├── 05f0a87a56d8477ca56d6780fb92a18b188dcc
# │   │   │   ├── 96ff4de8605cfaceacf85bcf98535058ed1a9b
# │   │   │   └── ac24d421f9e2b7c831b78cb611ffa343fd822e
# │   │   ├── 32/
# │   │   │   └── 1efb874557a51d30764e9f1a792f1e1b2a3cce
# │   │   ├── 33/
# │   │   │   └── 61183a419c188282a8545eaa8d8e298b8ffaab
# │   │   ├── 34/
# │   │   │   ├── 04f37e2e312757841abe20343588a7740768ca
# │   │   │   ├── 4db17ddbb7aea09b227835a7cd1c3265aeb172
# │   │   │   └── cdc4ca3d130acf967df82fca204420f016311e
# │   │   ├── 36/
# │   │   │   └── 3b3173b36ff346fbdec503b06a98aafec76270
# │   │   ├── 38/
# │   │   │   ├── 545c0407040f0eeec41897c38e2157d0088fe2
# │   │   │   ├── 5d660cec2b4e22e3b6e6a9da0568f41cb4ee47
# │   │   │   └── eed75c6ced227f71f68bfaeb871e3c84af051a
# │   │   ├── 3a/
# │   │   │   └── 45eb9022ba6ab1cf045a13c785ea3960f5e702
# │   │   ├── 3b/
# │   │   │   ├── 6f9908ad983277f57c2ee3c4089b2591132544
# │   │   │   └── f9843328a6359b6bd06e50010319c63da0d717
# │   │   ├── 3d/
# │   │   │   └── 4154936b42522fac84900c689a901ac12875c0
# │   │   ├── 3e/
# │   │   │   └── 632a10824ae7563f92057c19b71878b4d59c37
# │   │   ├── 3f/
# │   │   │   ├── 77c673204aea4a86d6b911228675c2f97085a6
# │   │   │   └── 826421a1d97b09797fad3d781a666a39eb45c9
# │   │   ├── 40/
# │   │   │   └── 539b0d0eccc28a77f85ab96184466f1f03d40d
# │   │   ├── 44/
# │   │   │   ├── 157df52ef25c5ee82f99b8af3a102faa556acf
# │   │   │   ├── 27dcd06694529ffe34b11c0adbd0af20380fd8
# │   │   │   └── 8df4f92d48cdb7ff90772f32ac9266f2ad8ac1
# │   │   ├── 47/
# │   │   │   └── d42efab842dc8070d078b5201ce442a53f7a99
# │   │   ├── 4a/
# │   │   │   └── 7ec836bbd461ab138bca0af426a3a7f299a9e7
# │   │   ├── 4b/
# │   │   │   ├── 1ba419f8502e8a520c53c9102b02924a34abc4
# │   │   │   ├── 380d259b18aee4034850769cd79381e6afde93
# │   │   │   ├── 591392e06d73110adad5f6f602ad0725ebf3cc
# │   │   │   ├── 8a36d249a05a0fe1575dc3d96ef7079dba6b07
# │   │   │   └── ae94ef8cf402f815de36beae8f82a245a676ce
# │   │   ├── 4f/
# │   │   │   └── e1acd82f7781ab6655cc96f810d9077cae2fc7
# │   │   ├── 51/
# │   │   │   └── 68d37fa36b9533f6922749a04f35e7ae8c60fd
# │   │   ├── 52/
# │   │   │   ├── 44f44a2200d4aa17a5413a4e8dcd444d1bc5b2
# │   │   │   ├── 66fb19ecb24d085a338bdace79a063326b1cff
# │   │   │   ├── 6d7234b6538603393d419ae2330b3fd6e57ee8
# │   │   │   └── ac1fd0034704d9c43dbb40678e126754d14726
# │   │   ├── 55/
# │   │   │   └── f6fabc8c697bd7c481824978549b7a68510007
# │   │   ├── 58/
# │   │   │   └── ffbde4ad99529f5ab1082633b190555e1aa0de
# │   │   ├── 59/
# │   │   │   ├── 9d1dcf2d5895cf492bb1c3704c3a534167acfc
# │   │   │   └── c084725f898d47969ffd1e76fe7c629825ebe9
# │   │   ├── 5a/
# │   │   │   ├── 56ef227a86d4d4d8130235bc2fb1f01ea88b29
# │   │   │   └── bb5c2c07ce603b5e1e75b5d5eb7dc309252107
# │   │   ├── 5b/
# │   │   │   └── 4ae7878486aa94b25304e83a3e8f48e5fafd9f
# │   │   ├── 5c/
# │   │   │   └── 532d0b57e272b220ee714326f4e8b280bb9826
# │   │   ├── 5d/
# │   │   │   ├── 4a2a65ea8294a65d82cbf3ab413d72a5f0dbd0
# │   │   │   └── c2bebd6a2da919c08597e98cea2498c0ca55e9
# │   │   ├── 5f/
# │   │   │   └── f318066d83f9da7a5a97f34f7d78e1a7696c7c
# │   │   ├── 61/
# │   │   │   ├── 12283bb7b2e0579d6f68fd682572a8c278a10b
# │   │   │   └── 6373c9ef62b509e681090109d904f4fafcee94
# │   │   ├── 62/
# │   │   │   └── fe94cc2d75cdb2ddba85873394382408e8ec83
# │   │   ├── 63/
# │   │   │   ├── 6f8ea702436d104d4d68788cf33cf888aa44c2
# │   │   │   └── cb023bd6afdb25b051bd1b1234bbe9be056f8c
# │   │   ├── 65/
# │   │   │   └── 35dffb598adaaffee1650dc6747780946e091d
# │   │   ├── 66/
# │   │   │   └── 5fd89dba1f934387eca646e7b610013464c32f
# │   │   ├── 67/
# │   │   │   └── 624dcf3040da30d56de0aa15138f4cbc832a8b
# │   │   ├── 69/
# │   │   │   ├── 1aeb82d0057a353637453f168872571a8e5328
# │   │   │   └── b46785432d33b9ff8ce19b7c9366987953b380
# │   │   ├── 6b/
# │   │   │   ├── 1bf0c28e81c79abfd7fc018bac32d216c0851a
# │   │   │   └── 6d1a21021b8b6c63cd6ab8e9409af2bfabf00e
# │   │   ├── 6c/
# │   │   │   └── b60000181dbd348963953ac8ac54afb46c63d5
# │   │   ├── 70/
# │   │   │   ├── 59e23142aae3d8bad6067fc734a6cffec779c9
# │   │   │   ├── 9ae8e30b066fa10e18e77dac51551ec5bc4719
# │   │   │   └── ac4d99b67e9a4d5fb23489e00e64bd54c34c04
# │   │   ├── 71/
# │   │   │   ├── 66744e606b68582c4bb17547ee72b4bf6b2420
# │   │   │   └── eba76293e4243293145e6a954991987b1bb27e
# │   │   ├── 74/
# │   │   │   ├── 48d5e8b5d2643c7c60e3304cb07749882919bf
# │   │   │   ├── 59901fc354acc7def0fc6638599fe4201ad8f0
# │   │   │   └── decd9ebb8d805201934266b3bda6a9d5831024
# │   │   ├── 75/
# │   │   │   └── ac4ec9744d4a0bb0450b13117c1dac1006694e
# │   │   ├── 76/
# │   │   │   └── 114bc03362242c3325ecda6ce6d02bb737880f
# │   │   ├── 77/
# │   │   │   └── 963473710224e7cda22fe4ed191d1b06ce5203
# │   │   ├── 78/
# │   │   │   ├── 47d6b4463e2d7dcc33c5d6b8838afc0aa865d1
# │   │   │   └── e7c1b2def864176df58342aa3ec7faf7677bfd
# │   │   ├── 79/
# │   │   │   └── dc8efed3447d6588baa2bb74122d56f3500038
# │   │   ├── 7c/
# │   │   │   └── d25c566fac11c7516a3d2611be4c98372f7b81
# │   │   ├── 7d/
# │   │   │   └── 75cc9a704a4d00c91595cbdd36c428487b9817
# │   │   ├── 7e/
# │   │   │   └── 3291082f46b512dd9504b5c6dc7a85dd2a585b
# │   │   ├── 80/
# │   │   │   └── 9c1f5828f86235347019a50e78b4b486a6a045
# │   │   ├── 81/
# │   │   │   ├── 674f1031654fe692e72c67ff555f3931126aa2
# │   │   │   └── 9369ceea0e441389935c0a65ce607b897f786b
# │   │   ├── 83/
# │   │   │   └── 9d07e2b8e9091dea25b2b4e3081adb1906d1f7
# │   │   ├── 84/
# │   │   │   ├── 60945e09b8da06d97eed4fe0be188442392547
# │   │   │   └── c590cedc56060f5ffd45ac4308ef450e192e05
# │   │   ├── 88/
# │   │   │   ├── 082d3c437279b138e63c41e1c4e5bd5498f9c4
# │   │   │   └── ad05b9ff413055b4d4e89dd3eec1c193fa20c6
# │   │   ├── 89/
# │   │   │   └── 4a44cc066a027465cd26d634948d56d13af9af
# │   │   ├── 8c/
# │   │   │   ├── c47c4872d9040bafa818a91a027faec1c55669
# │   │   │   ├── d4f101a91d864f52b340128fddc1e6b39cddbb
# │   │   │   ├── f6d8554e43891b0cf79ff022324f4a19d8259f
# │   │   │   └── fdc1a65c3db6fa8ec79855449f944c0f9d5444
# │   │   ├── 8e/
# │   │   │   └── 8172959225a75de086b38b433a0738bb3c1b7b
# │   │   ├── 8f/
# │   │   │   ├── 8f871630f62fd570a551b0f248d38cd2fa9cbe
# │   │   │   └── d7ce84da67f1f839f78f0efb558f03bd419eee
# │   │   ├── 90/
# │   │   │   └── f0440736d8a3762c95221beeea5a205e6aed9f
# │   │   ├── 93/
# │   │   │   └── de696435496b3cf918197d5f10fec4a5adda2e
# │   │   ├── 94/
# │   │   │   ├── 044b86dc196eab50432759d2d959db6f67b5a7
# │   │   │   ├── 080b351a7f4d350c6c6cd80c83c214dc3ac7df
# │   │   │   └── a22594942a4f89a90e998302cbc74e381b47d4
# │   │   ├── 96/
# │   │   │   └── a6df2f9e472e539b050e79b5dda40e6abed923
# │   │   ├── 97/
# │   │   │   ├── 6a26a0db49873d6bc4b326569c58fb633c1741
# │   │   │   └── 8b9b95d6262ca9fa05609ed451635c252024e2
# │   │   ├── 98/
# │   │   │   └── de9672b203ffb5b8e94cab77ff63be5490dec9
# │   │   ├── 9a/
# │   │   │   └── 8785afcadc6f23a994ae07a4837b948508a0ad
# │   │   ├── 9d/
# │   │   │   ├── 872a8e2cb2b10e27e663a264678da403d1905f
# │   │   │   └── f88961ea8ca6226e6a743769055bb764a384b7
# │   │   ├── a0/
# │   │   │   └── f71d60f5f0f584fcecd16fddd16beea6f2eef1
# │   │   ├── a4/
# │   │   │   └── bb0a80b3bb49a462e1382f9c6dfb60757822c1
# │   │   ├── a8/
# │   │   │   └── 443270503c577a5f4dba322713a44fcc526dde
# │   │   ├── a9/
# │   │   │   └── 5c6a637ba7f1120fc47410fa781c1ecc91591b
# │   │   ├── ae/
# │   │   │   ├── 1307ff5f4c48678621c240f8972d5a6e20b22c
# │   │   │   ├── 1d720b611f03dfe5d41e8b92072174eb6dd124
# │   │   │   ├── c8b7ae0dd528ffbbf5dc534c2b593d58820767
# │   │   │   └── dcbd2aaf42ff4c8116e3b8042939f42fa06f5b
# │   │   ├── af/
# │   │   │   ├── 2c4350d3a80315f7db4818cd6bccb96700f49c
# │   │   │   └── cb3504e9e2795980126b697e8f79bca3338a7a
# │   │   ├── b3/
# │   │   │   ├── 34750bb57f97932dfdc2624361e8a9b8db864c
# │   │   │   └── b309dd75edcfceeb749d93f8fc553bbdff8d21
# │   │   ├── b4/
# │   │   │   └── bfc9b24aa993977662352c881c6e42f99f77e0
# │   │   ├── b6/
# │   │   │   └── d5cb85767310ca056ce3307082eaacfa0748f4
# │   │   ├── b7/
# │   │   │   └── b628c0fa37895b29103a8c3aa92db67c12d6ed
# │   │   ├── b9/
# │   │   │   └── a9fec54dcdbdd94c5a6596c1f6141bdc0ea5d1
# │   │   ├── ba/
# │   │   │   ├── 1b77a89d4c3fd332d39b0b293e5da3b72349d4
# │   │   │   └── b331961ff6e449fa87151254ab8b6bb6138932
# │   │   ├── bb/
# │   │   │   └── 195043cfc07fa52741c6144d7378b5ba8be4c5
# │   │   ├── be/
# │   │   │   └── e9dcbe7b5f6072b1c35318d47ad71f2f051b5b
# │   │   ├── c1/
# │   │   │   └── bb6c7ac6a5ef28dbfff49ae96c85b85b3bd84b
# │   │   ├── c3/
# │   │   │   └── 20e9dad3da57b9390e67b61a96833aba9ea871
# │   │   ├── c4/
# │   │   │   ├── 192631f25b34d77a7f159aa0da0e3ae99c4ef4
# │   │   │   └── e3d804b57b625b16a36d767bfca6bbf63d414e
# │   │   ├── c5/
# │   │   │   └── 36c2e515902b29f8ab2529cc3a798b473dfde0
# │   │   ├── c6/
# │   │   │   ├── b7952a8f5463a33e9e521a8e1f1d902911b281
# │   │   │   ├── dff51f063cc732fdb5fe786a8966de85f4ebec
# │   │   │   └── eb31645e7f488c2236970be431e76d6d08bb4f
# │   │   ├── c7/
# │   │   │   └── 418817439b2f071c93a4a6cee831e996123c0b
# │   │   ├── ca/
# │   │   │   └── 3efc36580712ce98cf061ee4e453c4cd4c7e7c
# │   │   ├── cb/
# │   │   │   └── 9505581f2407a79ac8f1915ad99eebf0c97b33
# │   │   ├── cd/
# │   │   │   ├── 1c674f5e3a290a12386156500df3c50903a46b
# │   │   │   └── db836223797b74be238e78e7fe76ddf20bf9f5
# │   │   ├── cf/
# │   │   │   └── 8834662ca2f95dca24ba29491ab8c3717d398a
# │   │   ├── d2/
# │   │   │   ├── 89902f4c9d6c955ec453c0cc39533d4b622fc3
# │   │   │   └── aab1ce579b6f8e1e4d7e0ec186816d90fae1a2
# │   │   ├── d5/
# │   │   │   └── a74068091b9238c59ea3fc86ecc00d01027268
# │   │   ├── da/
# │   │   │   └── 2ce59585a188ad41fe2b23c94bafafc65e189b
# │   │   ├── db/
# │   │   │   ├── 583f45cc6bb2281e77e492ed018ccc55e47d38
# │   │   │   └── c06e4b6a29092ae8ef1811534216edcef2b453
# │   │   ├── dd/
# │   │   │   └── a17ffb90e6c2a99d8a4e38d8ca38b52e70fe1f
# │   │   ├── df/
# │   │   │   └── 5d1df2730433013f41bf2698cbe249b075aa02
# │   │   ├── e1/
# │   │   │   └── ba9a30fe032e630e50cc622a8719cab67b8a71
# │   │   ├── e3/
# │   │   │   ├── 5b5dbdc5ff85c65a4baa95b49505bb5af33f29
# │   │   │   └── 80325bc6e273d9142c2369883d2a4b2a069cf1
# │   │   ├── e5/
# │   │   │   └── 2837a43cd5462ef9786bf50d9c8dde845f9f32
# │   │   ├── e6/
# │   │   │   └── 57d9aa1eaf86b4c5151c0607b84781527c6ed0
# │   │   ├── e8/
# │   │   │   └── ebc711da23fc888a099ca4fe25b66ffabaa796
# │   │   ├── eb/
# │   │   │   ├── 52a7907362cc3392eb74892883f5d9e260b638
# │   │   │   └── e8581ffe5f3dfcc676927af4245c9282dd2d35
# │   │   ├── ec/
# │   │   │   ├── 0339b8f10741dee9689a1235ed30f796a631a4
# │   │   │   └── 1f0a7925fa84c67eb55c2de522a13147616885
# │   │   ├── ed/
# │   │   │   └── b5c78b1eaa147ce25488f417b4afd8d1dc7064
# │   │   ├── ee/
# │   │   │   ├── 1949ca32af57626ed8574919da11a570c9edea
# │   │   │   └── 338c3f0786ac322bdf49f5b4f72dec4cc02753
# │   │   ├── ef/
# │   │   │   └── a81a759df0eebeceefa6b138b5c5aca03db5f4
# │   │   ├── f1/
# │   │   │   └── 8fbad471c97df81fe93e4e265e70dff1cad511
# │   │   ├── f2/
# │   │   │   └── c76e5bda18a9842e24cd60d8787257da215ca7
# │   │   ├── f3/
# │   │   │   └── aed9ae43a2767fcd23685d6329982da9319987
# │   │   ├── f4/
# │   │   │   ├── 02040b3e5360b90f3a12ca2afab2cd7244e16f
# │   │   │   └── ff0a23cf8f53ee8b07fa4f2c8d939858d12ada
# │   │   ├── f5/
# │   │   │   ├── 2ef1374bc4eb913c99d092164b6d107806160b
# │   │   │   └── 8d75341661640267ea493cb7d3121d3a9cf504
# │   │   ├── f6/
# │   │   │   ├── 5d47974786ee51c258f680bd9be621629244f5
# │   │   │   ├── a8ac6fa419d0e8240c9faac0062aa97f5c23f0
# │   │   │   └── cf9ae0a8bec0a5be48b6012d10a12961b393b1
# │   │   ├── f8/
# │   │   │   ├── 15f63f99da80ad2be69e4021023ec2981eaea0
# │   │   │   └── 9f9734ff99a5aa9b4f7d0bd84e6b02fbc4985f
# │   │   ├── fb/
# │   │   │   └── 1a05f96422e89e6f02a37460349dfb42c55acc
# │   │   ├── fc/
# │   │   │   └── 981ce7ad6c42d2384f0ef74b73174b9302ee65
# │   │   ├── fd/
# │   │   │   └── 9628baedb1e73b7040c57796ae01187a8fcd40
# │   │   ├── fe/
# │   │   │   └── 9c61b9d53f94ef3c1b405b8a163f79f4510bf0
# │   │   ├── info/
# │   │   │   ├── commit-graph
# │   │   │   └── packs
# │   │   └── pack/
# │   │       ├── pack-70c57a8309936ddf2c1138a4e1079cf7ddb6d0e1.idx
# │   │       ├── pack-70c57a8309936ddf2c1138a4e1079cf7ddb6d0e1.pack
# │   │       ├── pack-8574339755c2549ce40ed95d3c16149a1466200e.idx
# │   │       └── pack-8574339755c2549ce40ed95d3c16149a1466200e.pack
# │   ├── ORIG_HEAD
# │   ├── packed-refs
# │   └── refs/
# │       ├── heads/
# │       │   ├── gh-pages
# │       │   └── main
# │       ├── remotes/
# │       │   ├── origin/
# │       │   │   ├── gh-pages
# │       │   │   ├── HEAD
# │       │   │   └── main
# │       │   └── upstream/
# │       └── tags/
# ├── .github/
# │   └── workflows/
# │       └── main.yml
# ├── .gitignore
# ├── .ipynb_checkpoints/
# │   ├── dev-checkpoint.ipynb
# │   ├── Expipe-checkpoint.ipynb
# │   ├── MetadataManager-checkpoint.ipynb
# │   ├── run_GUI-checkpoint.ipynb
# │   ├── test-checkpoint.ipynb
# │   ├── test_xarray-checkpoint.ipynb
# │   ├── trash_widget-checkpoint.ipynb
# │   ├── Untitled-checkpoint.ipynb
# │   ├── Untitled1-checkpoint.ipynb
# │   └── Untitled2-checkpoint.ipynb
# ├── __pycache__/
# │   └── run_GUI.cpython-38.pyc
# ├── apt.txt
# ├── CHANGELOG
# ├── dev.ipynb
# ├── dev_notebooks/
# │   ├── .ipynb_checkpoints/
# │   │   ├── dev-checkpoint.ipynb
# │   │   └── Untitled3-checkpoint.ipynb
# │   ├── __init__.py
# │   ├── db_read.ipynb
# │   ├── dev.ipynb
# │   ├── expipe/
# │   │   ├── data-management-workshop-NRSN-DLN-2019-master/
# │   │   │   ├── .gitignore
# │   │   │   ├── environment.yml
# │   │   │   ├── expipe/
# │   │   │   │   ├── .ipynb_checkpoints/
# │   │   │   │   │   └── expipe-tutorial-checkpoint.ipynb
# │   │   │   │   ├── EM acquisition/
# │   │   │   │   │   ├── actions/
# │   │   │   │   │   │   ├── measurements/
# │   │   │   │   │   │   │   ├── attributes.yaml
# │   │   │   │   │   │   │   ├── messages/
# │   │   │   │   │   │   │   └── modules/
# │   │   │   │   │   │   └── rhizotron/
# │   │   │   │   │   │       ├── attributes.yaml
# │   │   │   │   │   │       ├── messages/
# │   │   │   │   │   │       └── modules/
# │   │   │   │   │   ├── entities/
# │   │   │   │   │   │   └── rhizotron/
# │   │   │   │   │   │       ├── attributes.yaml
# │   │   │   │   │   │       ├── messages/
# │   │   │   │   │   │       │   └── 20210505T180530.yaml
# │   │   │   │   │   │       └── modules/
# │   │   │   │   │   │           └── info.yaml
# │   │   │   │   │   ├── expipe.yaml
# │   │   │   │   │   ├── modules/
# │   │   │   │   │   │   └── user_info.yaml
# │   │   │   │   │   └── templates/
# │   │   │   │   ├── ERT plant/
# │   │   │   │   │   ├── actions/
# │   │   │   │   │   │   ├── action_exported/
# │   │   │   │   │   │   │   ├── attributes.yaml
# │   │   │   │   │   │   │   ├── data/
# │   │   │   │   │   │   │   │   └── action_exported.csv
# │   │   │   │   │   │   │   ├── messages/
# │   │   │   │   │   │   │   └── modules/
# │   │   │   │   │   │   └── measurements/
# │   │   │   │   │   │       ├── attributes.yaml
# │   │   │   │   │   │       ├── messages/
# │   │   │   │   │   │       └── modules/
# │   │   │   │   │   ├── entities/
# │   │   │   │   │   │   └── rhizotron/
# │   │   │   │   │   │       ├── attributes.yaml
# │   │   │   │   │   │       ├── messages/
# │   │   │   │   │   │       │   └── 20210513T104124.yaml
# │   │   │   │   │   │       └── modules/
# │   │   │   │   │   │           └── info.yaml
# │   │   │   │   │   ├── expipe.yaml
# │   │   │   │   │   ├── modules/
# │   │   │   │   │   │   └── user_info.yaml
# │   │   │   │   │   └── templates/
# │   │   │   │   ├── expipe-tutorial.ipynb
# │   │   │   │   ├── make-data.ipynb
# │   │   │   │   ├── multimodal_rat_experiments/
# │   │   │   │   │   ├── actions/
# │   │   │   │   │   │   ├── 180_surgery/
# │   │   │   │   │   │   │   ├── attributes.yaml
# │   │   │   │   │   │   │   ├── messages/
# │   │   │   │   │   │   │   └── modules/
# │   │   │   │   │   │   └── rat_180/
# │   │   │   │   │   │       ├── attributes.yaml
# │   │   │   │   │   │       ├── messages/
# │   │   │   │   │   │       └── modules/
# │   │   │   │   │   │           └── info.yaml
# │   │   │   │   │   ├── entities/
# │   │   │   │   │   │   ├── rat_180/
# │   │   │   │   │   │   │   ├── attributes.yaml
# │   │   │   │   │   │   │   ├── messages/
# │   │   │   │   │   │   │   └── modules/
# │   │   │   │   │   │   │       └── info.yaml
# │   │   │   │   │   │   ├── rat_181/
# │   │   │   │   │   │   │   ├── attributes.yaml
# │   │   │   │   │   │   │   ├── messages/
# │   │   │   │   │   │   │   └── modules/
# │   │   │   │   │   │   └── rat_183/
# │   │   │   │   │   │       ├── attributes.yaml
# │   │   │   │   │   │       ├── messages/
# │   │   │   │   │   │       └── modules/
# │   │   │   │   │   ├── expipe.yaml
# │   │   │   │   │   ├── modules/
# │   │   │   │   │   │   └── user_info.yaml
# │   │   │   │   │   └── templates/
# │   │   │   │   ├── templates/
# │   │   │   │   │   ├── anaesthesia_isoflurane.yaml
# │   │   │   │   │   ├── anaesthesia_ketamine.yaml
# │   │   │   │   │   ├── implant_drive_mecr.yaml
# │   │   │   │   │   ├── injection_ms.yaml
# │   │   │   │   │   ├── optic_fibre.yaml
# │   │   │   │   │   └── subject.yaml
# │   │   │   │   └── test/
# │   │   │   │       ├── actions/
# │   │   │   │       │   └── rat_180/
# │   │   │   │       │       ├── attributes.yaml
# │   │   │   │       │       ├── messages/
# │   │   │   │       │       └── modules/
# │   │   │   │       │           └── info.yaml
# │   │   │   │       ├── entities/
# │   │   │   │       │   └── rat_183/
# │   │   │   │       │       ├── attributes.yaml
# │   │   │   │       │       ├── messages/
# │   │   │   │       │       └── modules/
# │   │   │   │       ├── expipe.yaml
# │   │   │   │       ├── modules/
# │   │   │   │       │   └── user_info.yaml
# │   │   │   │       └── templates/
# │   │   │   │           ├── anaesthesia_isoflurane.yaml
# │   │   │   │           ├── anaesthesia_ketamine.yaml
# │   │   │   │           ├── implant_drive_mecr.yaml
# │   │   │   │           ├── injection_ms.yaml
# │   │   │   │           ├── optic_fibre.yaml
# │   │   │   │           └── subject.yaml
# │   │   │   ├── nwb_tutorials/
# │   │   │   │   ├── images/
# │   │   │   │   │   ├── electrodes_table.png
# │   │   │   │   │   ├── lfp.png
# │   │   │   │   │   └── position.png
# │   │   │   │   ├── NWB_tutorial_2019.ipynb
# │   │   │   │   └── NWB_tutorial_2019.m
# │   │   │   ├── README.md
# │   │   │   ├── requirements.txt
# │   │   │   └── spikeinterface/
# │   │   │       ├── check-installed-sorters.ipynb
# │   │   │       ├── spikeInterface-tutorial.ipynb
# │   │   │       └── tetrode_16.prb
# │   │   ├── test/
# │   │   │   ├── actions/
# │   │   │   │   └── something/
# │   │   │   │       ├── attributes.yaml
# │   │   │   │       ├── messages/
# │   │   │   │       └── modules/
# │   │   │   ├── entities/
# │   │   │   ├── expipe.yaml
# │   │   │   ├── modules/
# │   │   │   └── templates/
# │   │   └── test_expipe.py
# │   ├── test/
# │   │   ├── actions/
# │   │   │   └── something/
# │   │   │       ├── attributes.yaml
# │   │   │       ├── messages/
# │   │   │       └── modules/
# │   │   ├── entities/
# │   │   ├── expipe.yaml
# │   │   ├── modules/
# │   │   └── templates/
# │   ├── test.ipynb
# │   ├── test.py
# │   ├── test_xarray.ipynb
# │   ├── Untitled.ipynb
# │   ├── Untitled1.ipynb
# │   ├── Untitled2.ipynb
# │   └── Untitled3.ipynb
# ├── docsrc/
# │   ├── beginner.rst
# │   ├── CAGS.png
# │   ├── conf.py
# │   ├── contibutors.rst
# │   ├── getting-started.rst
# │   ├── images/
# │   ├── index.rst
# │   ├── Intro_GUI.mp4
# │   ├── refs.bib
# │   └── terms_of_use.rst
# ├── environment.yml
# ├── experiment.exdir/
# │   ├── exdir.yaml
# │   └── type1/
# │       ├── attributes.yaml
# │       ├── data/
# │       │   ├── attributes.yaml
# │       │   ├── data.npy
# │       │   └── exdir.yaml
# │       └── exdir.yaml
# ├── Expipe.ipynb
# ├── harvesters/
# │   ├── em emagpy.ipynb
# │   ├── em_import.py
# │   └── ert_import.py
# ├── img/
# │   ├── CAGS_metadata_Manager.png
# │   └── logo.png
# ├── lib/
# │   ├── .gitignore
# │   ├── __init__.py
# │   ├── __pycache__/
# │   │   ├── __init__.cpython-37.pyc
# │   │   └── __init__.cpython-38.pyc
# │   └── geometadp/
# │       ├── .ipynb_checkpoints/
# │       │   └── test_xarray-checkpoint.ipynb
# │       ├── __init__.py
# │       ├── __pycache__/
# │       │   ├── __init__.cpython-36.pyc
# │       │   ├── __init__.cpython-37.pyc
# │       │   ├── __init__.cpython-38.pyc
# │       │   ├── about.cpython-38.pyc
# │       │   ├── EM.cpython-38.pyc
# │       │   ├── md_manager.cpython-37.pyc
# │       │   ├── md_manager.cpython-38.pyc
# │       │   ├── ownership.cpython-38.pyc
# │       │   ├── pipeline.cpython-38.pyc
# │       │   ├── save_export.cpython-38.pyc
# │       │   ├── test.cpython-37.pyc
# │       │   ├── test_diroutputs.cpython-38.pyc
# │       │   └── test_upload.cpython-37.pyc
# │       ├── about.py
# │       ├── EM.py
# │       ├── md_manager.py
# │       ├── md_manager_light.py
# │       ├── ownership.py
# │       ├── pipeline.py
# │       ├── read_db.py
# │       ├── save_export.py
# │       └── zip_manager.py
# ├── LICENSE
# ├── MetadataManager.ipynb
# ├── prep_exe/
# │   └── cmd_list.txt
# ├── project.exdir/
# │   ├── Data/
# │   │   └── exdir.yaml
# │   └── exdir.yaml
# ├── project.zip
# ├── project_test/
# │   ├── actions/
# │   │   └── acquisition/
# │   │       ├── attributes.yaml
# │   │       ├── messages/
# │   │       └── modules/
# │   ├── entities/
# │   │   └── equipment/
# │   │       ├── attributes.yaml
# │   │       ├── messages/
# │   │       └── modules/
# │   ├── expipe.yaml
# │   ├── modules/
# │   │   └── project-module.yaml
# │   └── templates/
# ├── Readme.md
# ├── requirements.txt
# ├── run_GUI.ipynb
# ├── run_GUI.py
# ├── run_GUI.spec
# ├── setup.py
# ├── test_data/
# │   ├── 01_Syscal/
# │   │   ├── data_normal.bin
# │   │   ├── data_normal.txt
# │   │   ├── data_reciprocal.bin
# │   │   ├── data_reciprocal.txt
# │   │   ├── elec.dat
# │   │   ├── elem.dat
# │   │   ├── grid.png
# │   │   ├── Pictures/
# │   │   │   └── picture1.png
# │   │   ├── reda_test.ipynb
# │   │   └── test_syscal_02.py
# │   ├── EM_data/
# │   │   └── EM_test_coverCrop.csv
# │   ├── Fig2import/
# │   │   └── MapGatherTown.PNG
# │   ├── json2import.json
# │   ├── json_backup.json
# │   ├── json_test.json
# │   └── Spatial_data/
# │       ├── 2dline.csv
# │       ├── europe_110.geo.json
# │       └── geojson2import.geo.json
# ├── test_xarray.ipynb
# ├── trash_widget.ipynb
# ├── Untitled.ipynb
# └── Untitled1.ipynb
